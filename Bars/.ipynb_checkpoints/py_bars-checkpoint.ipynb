# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis,bars_in_cities)

plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("10k bars per household")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.xticks(x_axis,cities)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x114e7ac90>,
#   <matplotlib.axis.XTick at 0x114e7a410>,
#   <matplotlib.axis.XTick at 0x114e17a10>,
#   <matplotlib.axis.XTick at 0x11559e7d0>,
#   <matplotlib.axis.XTick at 0x11559ea90>],
#  <a list of 5 Text xticklabel objects>)

# %%
# Save an image of the chart and print it to the screen
plt.savefig("BarsSolved.png")
